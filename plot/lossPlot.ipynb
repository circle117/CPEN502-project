# %%
import pandas as pd
import matplotlib.pyplot as plt
filePath = "../data/result/bipolarLoss-momentum0.9test.csv"

# %%
df = pd.read_csv(filePath)
df
# Out:
#     epoch     loss1     loss2     loss3     loss4     loss5     loss6  \
# 0       0  0.680281  0.687017  0.701143  0.719617  0.569534  0.549900
# 1       1  0.651984  0.521910  0.590593  0.680974  0.543137  0.603921
# 2       2  0.343163  0.368874  0.482586  0.354457  0.504729  0.514955
# 3       3  0.118949  0.101430  0.412692  0.146175  0.486710  0.156517
# 4       4  0.030780  0.057576  0.240641  0.134058  0.479110  0.040143
# 5       5       NaN  0.012027  0.030773  0.044556  0.469503       NaN
# 6       6       NaN       NaN       NaN       NaN  0.448398       NaN
# 7       7       NaN       NaN       NaN       NaN  0.391237       NaN
# 8       8       NaN       NaN       NaN       NaN  0.258481       NaN
# 9       9       NaN       NaN       NaN       NaN  0.216065       NaN
# 10     10       NaN       NaN       NaN       NaN  0.128957       NaN
# 11     11       NaN       NaN       NaN       NaN  0.072065       NaN
# ...

# %%
plt.plot(df["epoch"], df["loss1"], label="No.1")
plt.plot(df["epoch"], df["loss2"], label="No.2")
plt.plot(df["epoch"], df["loss3"], label="No.3")
plt.plot(df["epoch"], df["loss4"], label="No.4")
plt.plot(df["epoch"], df["loss5"], label="No.5")
plt.plot(df["epoch"], df["loss6"], label="No.6")
plt.plot(df["epoch"], df["loss7"], label="No.7")
plt.plot(df["epoch"], df["loss8"], label="No.8")
plt.plot(df["epoch"], df["loss9"], label="No.9")
plt.plot(df["epoch"], df["loss10"], label="No.10")
plt.legend()
plt.xlabel("number of epochs")
plt.ylabel("squared error")
plt.savefig("./res/bipolarLoss09test.png")
