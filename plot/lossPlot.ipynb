# %%
import pandas as pd
import matplotlib.pyplot as plt
filePath = "../data/result/xorLoss-momentum0.9.csv"

# %%
df = pd.read_csv(filePath)
df
# Out:
#      epoch     loss1     loss2     loss3     loss4     loss5     loss6  \
# 0        0  0.679287  0.652484  0.591662  0.574655  0.629257  0.513670
# 1        1  0.633439  0.606203  0.559332  0.547971  0.588583  0.513639
# 2        2  0.566599  0.547166  0.526539  0.522744  0.539465  0.513635
# 3        3  0.522445  0.519522  0.518090  0.517693  0.518146  0.513652
# 4        4  0.519843  0.525378  0.524386  0.523047  0.523324  0.513683
# ..     ...       ...       ...       ...       ...       ...       ...
# 504    504       NaN       NaN  0.053919       NaN       NaN       NaN
# 505    505       NaN       NaN  0.052464       NaN       NaN       NaN
# 506    506       NaN       NaN  0.051071       NaN       NaN       NaN
# 507    507       NaN       NaN  0.049736       NaN       NaN       NaN
# 508    508       NaN       NaN       NaN       NaN       NaN       NaN
#
#         loss7     loss8     loss9    loss10
# 0    0.550756  0.631187  0.660537  0.583595
# 1    0.534111  0.591397  0.616679  0.554962
# 2    0.520452  0.541932  0.556311  0.525410
# 3    0.519637  0.518168  0.519835  0.516801
# 4    0.523267  0.521715  0.518775  0.521954
# ..        ...       ...       ...       ...
# 504  0.049877       NaN       NaN       NaN
# 505       NaN       NaN       NaN       NaN
# 506       NaN       NaN       NaN       NaN
# 507       NaN       NaN       NaN       NaN
# 508       NaN       NaN       NaN       NaN
#
# [509 rows x 11 columns]

# %%
plt.plot(df["epoch"], df["loss1"], label="No.1")
plt.plot(df["epoch"], df["loss2"], label="No.2")
plt.plot(df["epoch"], df["loss3"], label="No.3")
plt.plot(df["epoch"], df["loss4"], label="No.4")
plt.plot(df["epoch"], df["loss5"], label="No.5")
plt.plot(df["epoch"], df["loss6"], label="No.6")
plt.plot(df["epoch"], df["loss7"], label="No.7")
plt.plot(df["epoch"], df["loss8"], label="No.8")
plt.plot(df["epoch"], df["loss9"], label="No.9")
plt.plot(df["epoch"], df["loss10"], label="No.10")
plt.legend()
plt.xlabel("number of epochs")
plt.ylabel("total error")
plt.savefig("./res/xorLoss09.png")
